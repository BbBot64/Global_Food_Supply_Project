# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\rho25\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (8.0.28)
# Requirement already satisfied: protobuf>=3.0.0 in c:\users\rho25\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from mysql-connector-python) (3.20.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import mysql.connector

# %% [markdown]
# ## Taking Finalized Datasets and putting them into Pandas Dataframes

# %%
weather = pd.read_csv('Berkeley_Weather_Final.csv')
co2 = pd.read_csv('owid-co2-data-final.csv')
crops = pd.read_csv('PSD_Grains_Final.csv')
coor = pd.read_csv('CountryCoord.csv')

# %% [markdown]
# ## Sorting Dataframes by Country and Year

# %%
weather_sorted = weather.sort_values(['Country', 'Year'])

# %%
co2_sorted = co2.sort_values(['country', 'year'])

# %%
crops_sorted = crops.sort_values(['Country_Name', 'Market_Year'])

# %%
weather_sorted = weather_sorted.drop('Instances', axis = 1)

# %% [markdown]
# ## Inserting Country Coordinates

# %%
coor = coor.drop('Unnamed: 0', axis = 1)

# %%
coordinates = coor.values.tolist()

# %%
# Creating a connection to your MySQL Server 
# Put your MySQL Server/Workbench password
Coor_Info = mysql.connector.connect(
    host='localhost',
    user='root',
    passwd='your_password',
    database = 'global_country_info')

if (Coor_Info):
    print("Connection Successful")
else:
    print("Connection Failed")
# Out:
# Connection Successful

# %%
# Create a cursor from the connection made
coor_cursor = Coor_Info.cursor() 
    
coor_statement = "INSERT INTO CountryLocation (Latitude, Longitude, Country) VALUES (%s, %s, %s)"

coor_cursor.executemany(coor_statement, coordinates)
  
Coor_Info.commit()
    
coor_cursor.execute("SELECT * FROM CountryLocation;")
coor_results_final = coor_cursor.fetchall()

# %%
Coor_DF = pd.DataFrame(coor_results_final, columns= ["country", "latitude", "longitude"])

# %%
coor_cursor.close()
Coor_Info.close()

# %%
Coor_DF
# Out:
#          country    latitude   longitude
# 0    Afghanistan   33.939110   67.709953
# 1        Albania   41.153332   20.168331
# 2        Algeria   28.033886    1.659626
# 3         Angola  -11.202692   17.873887
# 4      Argentina  -38.416097  -63.616672
# ..           ...         ...         ...
# 131    Venezuela    6.423750  -66.589730
# 132      Vietnam   14.058324  108.277199
# 133        Yemen   15.552727   48.516388
# 134       Zambia  -13.133897   27.849332
# 135     Zimbabwe  -19.015438   29.154857
#
# [136 rows x 3 columns]

# %% [markdown]
# ## Join Temperature Data to CO2 data

# %%
co2_sorted = co2_sorted.drop("Unnamed: 0", axis=1)

# %%
weather_sorted.rename(columns = {'Country': 'country', 'Year': 'year'}, inplace = True)

# %%
country_sorted_new = pd.merge(weather_sorted, co2_sorted, on = ['country', 'year'], how = 'left')

# %%
country_sorted_new.isna().sum()
# Out:
# year                                       0
# country                                    0
# Yearly Average Temperature                 0
# Yearly Average Temperature Uncertainty     0
# iso_code                                  86
# trade_co2                                 86
# cement_co2                                86
# coal_co2                                  86
# flaring_co2                               86
# gas_co2                                   86
# oil_co2                                   86
# other_industry_co2                        86
# consumption_co2                           86
# total_ghg                                 86
# total_ghg_excluding_lucf                  86
# methane                                   86
# nitrous_oxide                             86
# population                                86
# gdp                                       86
# primary_energy_consumption                86
# dtype: int64

# %%
country_sorted_new[country_sorted_new['country'] == 'Bhutan']= country_sorted_new[country_sorted_new['country'] == 'Bhutan'].fillna({'iso_code': 'BTN'})

# %%
country_sorted_new[country_sorted_new['country'] == 'Oman'] = country_sorted_new[country_sorted_new['country'] == 'Oman'].fillna({'iso_code': 'OMN'})

# %%
country_sorted_new[country_sorted_new['country'] == 'Botswana'] = country_sorted_new[country_sorted_new['country'] == 'Botswana'].fillna({'iso_code': 'BWA'})

# %%
country_sorted_new[country_sorted_new['country'] == 'Namibia'] = country_sorted_new[country_sorted_new['country'] == 'Namibia'].fillna({'iso_code': 'NAM'})

# %%
country_sorted_new[country_sorted_new['country'] == 'Lesotho'] = country_sorted_new[country_sorted_new['country'] == 'Lesotho'].fillna({'iso_code': 'LSO'})

# %% [markdown]
# ## IMPUTATION OF DATA FOR COUNTRIES THAT DIDN'T START REPORTING IN 1960

# %%
from fancyimpute import KNN

# %%
numeric_cols = country_sorted_new.select_dtypes(include='number').columns.tolist()

# %%
country_sorted_new[numeric_cols] = KNN(k=10).fit_transform(country_sorted_new[numeric_cols])
# Out:
# Imputing row 1/7208 with 0 missing, elapsed time: 4.878
# Imputing row 101/7208 with 0 missing, elapsed time: 4.878
# Imputing row 201/7208 with 0 missing, elapsed time: 4.878
# Imputing row 301/7208 with 0 missing, elapsed time: 4.878
# Imputing row 401/7208 with 0 missing, elapsed time: 4.878
# Imputing row 501/7208 with 0 missing, elapsed time: 4.879
# Imputing row 601/7208 with 0 missing, elapsed time: 4.879
# Imputing row 701/7208 with 0 missing, elapsed time: 4.882
# Imputing row 801/7208 with 15 missing, elapsed time: 4.884
# Imputing row 901/7208 with 0 missing, elapsed time: 4.886
# Imputing row 1001/7208 with 0 missing, elapsed time: 4.887
# Imputing row 1101/7208 with 0 missing, elapsed time: 4.887
# Imputing row 1201/7208 with 0 missing, elapsed time: 4.887
# Imputing row 1301/7208 with 0 missing, elapsed time: 4.887
# Imputing row 1401/7208 with 0 missing, elapsed time: 4.887
# Imputing row 1501/7208 with 0 missing, elapsed time: 4.887
# Imputing row 1601/7208 with 0 missing, elapsed time: 4.888
# Imputing row 1701/7208 with 0 missing, elapsed time: 4.888
# Imputing row 1801/7208 with 0 missing, elapsed time: 4.888
# Imputing row 1901/7208 with 0 missing, elapsed time: 4.888
# Imputing row 2001/7208 with 0 missing, elapsed time: 4.888
# Imputing row 2101/7208 with 0 missing, elapsed time: 4.888
# Imputing row 2201/7208 with 0 missing, elapsed time: 4.889
# Imputing row 2301/7208 with 0 missing, elapsed time: 4.889
# Imputing row 2401/7208 with 0 missing, elapsed time: 4.889
# Imputing row 2501/7208 with 0 missing, elapsed time: 4.889
# Imputing row 2601/7208 with 0 missing, elapsed time: 4.889
# Imputing row 2701/7208 with 0 missing, elapsed time: 4.889
# Imputing row 2801/7208 with 0 missing, elapsed time: 4.890
# Imputing row 2901/7208 with 0 missing, elapsed time: 4.890
# Imputing row 3001/7208 with 0 missing, elapsed time: 4.890
# Imputing row 3101/7208 with 0 missing, elapsed time: 4.890
# Imputing row 3201/7208 with 0 missing, elapsed time: 4.890
# Imputing row 3301/7208 with 0 missing, elapsed time: 4.891
# Imputing row 3401/7208 with 0 missing, elapsed time: 4.891
# Imputing row 3501/7208 with 0 missing, elapsed time: 4.891
# Imputing row 3601/7208 with 0 missing, elapsed time: 4.900
# Imputing row 3701/7208 with 0 missing, elapsed time: 4.900
# Imputing row 3801/7208 with 0 missing, elapsed time: 4.900
# Imputing row 3901/7208 with 0 missing, elapsed time: 4.901
# Imputing row 4001/7208 with 0 missing, elapsed time: 4.901
# Imputing row 4101/7208 with 0 missing, elapsed time: 4.901
# Imputing row 4201/7208 with 0 missing, elapsed time: 4.901
# Imputing row 4301/7208 with 0 missing, elapsed time: 4.901
# Imputing row 4401/7208 with 15 missing, elapsed time: 4.902
# Imputing row 4501/7208 with 0 missing, elapsed time: 4.911
# Imputing row 4601/7208 with 0 missing, elapsed time: 4.911
# Imputing row 4701/7208 with 0 missing, elapsed time: 4.911
# Imputing row 4801/7208 with 0 missing, elapsed time: 4.913
# Imputing row 4901/7208 with 0 missing, elapsed time: 4.913
# Imputing row 5001/7208 with 0 missing, elapsed time: 4.913
# Imputing row 5101/7208 with 0 missing, elapsed time: 4.913
# Imputing row 5201/7208 with 0 missing, elapsed time: 4.913
# Imputing row 5301/7208 with 0 missing, elapsed time: 4.913
# Imputing row 5401/7208 with 0 missing, elapsed time: 4.914
# Imputing row 5501/7208 with 0 missing, elapsed time: 4.914
# Imputing row 5601/7208 with 0 missing, elapsed time: 4.914
# Imputing row 5701/7208 with 0 missing, elapsed time: 4.914
# Imputing row 5801/7208 with 0 missing, elapsed time: 4.914
# Imputing row 5901/7208 with 0 missing, elapsed time: 4.914
# Imputing row 6001/7208 with 0 missing, elapsed time: 4.915
# Imputing row 6101/7208 with 0 missing, elapsed time: 4.915
# Imputing row 6201/7208 with 0 missing, elapsed time: 4.915
# Imputing row 6301/7208 with 0 missing, elapsed time: 4.915
# Imputing row 6401/7208 with 0 missing, elapsed time: 4.915
# Imputing row 6501/7208 with 0 missing, elapsed time: 4.916
# Imputing row 6601/7208 with 0 missing, elapsed time: 4.916
# Imputing row 6701/7208 with 0 missing, elapsed time: 4.916
# Imputing row 6801/7208 with 0 missing, elapsed time: 4.916
# Imputing row 6901/7208 with 0 missing, elapsed time: 4.916
# Imputing row 7001/7208 with 0 missing, elapsed time: 4.916
# Imputing row 7101/7208 with 0 missing, elapsed time: 4.917
# Imputing row 7201/7208 with 0 missing, elapsed time: 4.917

# %%
country_sorted_new.isna().sum()
# Out:
# year                                      0
# country                                   0
# Yearly Average Temperature                0
# Yearly Average Temperature Uncertainty    0
# iso_code                                  0
# trade_co2                                 0
# cement_co2                                0
# coal_co2                                  0
# flaring_co2                               0
# gas_co2                                   0
# oil_co2                                   0
# other_industry_co2                        0
# consumption_co2                           0
# total_ghg                                 0
# total_ghg_excluding_lucf                  0
# methane                                   0
# nitrous_oxide                             0
# population                                0
# gdp                                       0
# primary_energy_consumption                0
# dtype: int64

# %%
country_sorted_new
# Out:
#         year      country  Yearly Average Temperature  \
# 0     1960.0  Afghanistan                   13.985417
# 1     1961.0  Afghanistan                   14.064917
# 2     1962.0  Afghanistan                   13.768667
# 3     1963.0  Afghanistan                   15.033417
# 4     1964.0  Afghanistan                   13.084917
# ...      ...          ...                         ...
# 7203  2008.0     Zimbabwe                   21.545583
# 7204  2009.0     Zimbabwe                   21.377250
# 7205  2010.0     Zimbabwe                   21.986250
# 7206  2011.0     Zimbabwe                   21.602417
# 7207  2012.0     Zimbabwe                   21.521333
#
#       Yearly Average Temperature Uncertainty iso_code  trade_co2  cement_co2  \
# 0                                   0.441833      AFG   4.825121       0.018
# 1                                   0.398083      AFG   2.799278       0.022
# 2                                   0.406167      AFG   5.166143       0.029
# 3                                   0.401250      AFG   5.396530       0.051
# 4                                   0.449417      AFG   2.222403       0.062
# ...                                      ...      ...        ...         ...
# 7203                                0.433000      ZWE   1.575000       0.154
# 7204                                0.436417      ZWE   2.595000       0.270
# 7205                                0.409667      ZWE   1.497000       0.308
# 7206                                0.393417      ZWE   1.046000       0.382
# 7207                                0.538500      ZWE   2.895000       0.566
#
#       coal_co2  flaring_co2    gas_co2  oil_co2  other_industry_co2  \
# 0        0.127     0.468075   6.331716    0.269            0.019286
# 1        0.176     0.548903   7.603425    0.293            0.020133
# 2        0.297     0.694566   9.074737    0.363            0.021839
# 3        0.264     0.475554  10.127002    0.392            0.027291
# 4        0.300     0.586721  18.013322    0.476            0.033849
# ...        ...          ...        ...      ...                 ...
# 7203     5.958     1.531992   4.544799    1.608            0.039210
# 7204     3.559     1.526867  14.497649    1.648            0.036948
# 7205     5.632     1.465790  12.835969    1.938            0.026987
# 7206     6.101     1.452206  11.580721    3.261            0.041595
# 7207     3.624     1.310834   6.885178    3.693            0.044153
#
#       consumption_co2  total_ghg  total_ghg_excluding_lucf    methane  \
# 0           52.630406  43.612099                 26.255411  18.762165
# 1           33.225018  43.999025                 26.648972  19.038970
# 2           54.138556  44.214932                 26.863575  19.168252
# 3           59.306020  44.427530                 27.077185  19.308069
# 4           21.192878  44.667891                 27.308836  19.459534
# ...               ...        ...                       ...        ...
# 7203         9.295000  35.350000                 24.150000  10.560000
# 7204         8.071000  36.270000                 25.170000  10.920000
# 7205         9.375000  39.300000                 28.080000  11.450000
# 7206        10.790000  42.040000                 30.550000  11.900000
# 7207        10.778000  42.360000                 30.780000  11.850000
#
#       nitrous_oxide  population           gdp  primary_energy_consumption
# 0          6.944695   8996967.0  1.303325e+10                    2.949846
# 1          7.049714   9169406.0  1.314629e+10                    3.017879
# 2          7.099816   9351442.0  1.336763e+10                    3.131269
# 3          7.149380   9543200.0  1.363030e+10                    3.257176
# 4          7.211517   9744772.0  1.387050e+10                    3.278518
# ...             ...         ...           ...                         ...
# 7203       5.970000  12379553.0  1.505022e+10                   41.277000
# 7204       6.360000  12526964.0  1.627576e+10                   41.112000
# 7205       6.770000  12697728.0  1.791838e+10                   46.599000
# 7206       6.950000  12894323.0  1.955407e+10                   51.260000
# 7207       6.650000  13115149.0  2.090997e+10                   55.756000
#
# [7208 rows x 20 columns]

# %%
country_data = country_sorted_new.values.tolist()

# %% [markdown]
# ## Inserting Country Data into the Country Table

# %%
# Creating a connection to your MySQL Server 
# Put your MySQL Server/Workbench password
Countries_Info = mysql.connector.connect(
    host='localhost',
    user='root',
    passwd='your_password',
    database = 'global_country_info')

if (Countries_Info):
    print("Connection Successful")
else:
    print("Connection Failed")
# Out:
# Connection Successful

# %%
# Create a cursor from the connection made
country_cursor = Countries_Info.cursor()

# %%
country_statement = "INSERT INTO Countries (Year, Country, yearly_average_temperature, yearly_average_temperature_uncertainty, ISO_Code, Trade_co2, Cement_co2, Coal_co2, Flaring_co2, Gas_co2, Oil_co2, Other_industry_co2, Consumption_co2, Total_ghg, Total_ghg_excl_lucf, Methane, Nitrous_oxide, Population, GDP, Primary_Energy_Consumption) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"

country_cursor.executemany(country_statement, country_data)
  
Countries_Info.commit()
    
country_cursor.execute("SELECT * FROM Countries;")
country_results_final = country_cursor.fetchall()

# %%
# Using the countries results saved from the previous Query to insert
# Into a Pandas DataFrame to be used later
Country_DF = pd.DataFrame(country_results_final, columns= ["Record_ID", "Country", "Year", "ISO_Code", "Yearly_Average_Temperature", "Yearly_Average_Temperature_Uncertainty", "Methane", "Nitrous_oxide", "Total_ghg", "Total_ghg_excl_lucf", "Trade_co2", "Cement_co2", "Coal_co2", "Flaring_co2", "Gas_co2", "Oil_co2", "Other_industry_co2", "Consumption_co2", "Population", "GDP", "Primary Energy Consumption"])

# %%
Country_DF
# Out:
#       Record_ID      Country  Year ISO_Code Yearly_Average_Temperature  \
# 0             1  Afghanistan  1960      AFG                13.98541667
# 1             2  Afghanistan  1961      AFG                14.06491667
# 2             3  Afghanistan  1962      AFG                13.76866667
# 3             4  Afghanistan  1963      AFG                15.03341667
# 4             5  Afghanistan  1964      AFG                13.08491667
# ...         ...          ...   ...      ...                        ...
# 7203       7204     Zimbabwe  2008      ZWE                21.54558333
# 7204       7205     Zimbabwe  2009      ZWE                21.37725000
# 7205       7206     Zimbabwe  2010      ZWE                21.98625000
# 7206       7207     Zimbabwe  2011      ZWE                21.60241667
# 7207       7208     Zimbabwe  2012      ZWE                21.52133333
#
#      Yearly_Average_Temperature_Uncertainty Methane Nitrous_oxide Total_ghg  \
# 0                         0.441833333333333   18.76          6.94     43.61
# 1                         0.398083333333333   19.04          7.05     44.00
# 2                         0.406166666666667   19.17          7.10     44.21
# 3                         0.401250000000000   19.31          7.15     44.43
# 4                         0.449416666666667   19.46          7.21     44.67
# ...                                     ...     ...           ...       ...
# 7203                      0.433000000000000   10.56          5.97     35.35
# 7204                      0.436416666666667   10.92          6.36     36.27
# 7205                      0.409666666666667   11.45          6.77     39.30
# 7206                      0.393416666666667   11.90          6.95     42.04
# 7207                      0.538500000000000   11.85          6.65     42.36
#
#      Total_ghg_excl_lucf  ... Cement_co2 Coal_co2 Flaring_co2 Gas_co2 Oil_co2  \
# 0                  26.26  ...      0.018    0.127       0.468   6.332   0.269
# 1                  26.65  ...      0.022    0.176       0.549   7.603   0.293
# 2                  26.86  ...      0.029    0.297       0.695   9.075   0.363
# 3                  27.08  ...      0.051    0.264       0.476  10.127   0.392
# 4                  27.31  ...      0.062    0.300       0.587  18.013   0.476
# ...                  ...  ...        ...      ...         ...     ...     ...
# 7203               24.15  ...      0.154    5.958       1.532   4.545   1.608
# 7204               25.17  ...      0.270    3.559       1.527  14.498   1.648
# 7205               28.08  ...      0.308    5.632       1.466  12.836   1.938
# 7206               30.55  ...      0.382    6.101       1.452  11.581   3.261
# 7207               30.78  ...      0.566    3.624       1.311   6.885   3.693
#
#      Other_industry_co2 Consumption_co2 Population          GDP  \
# 0                 0.019          52.630    8996967  13033254000
# 1                 0.020          33.225    9169406  13146287000
# 2                 0.022          54.139    9351442  13367634000
# 3                 0.027          59.306    9543200  13630298000
# 4                 0.034          21.193    9744772  13870504000
# ...                 ...             ...        ...          ...
# 7203              0.039           9.295   12379553  15050220990
# 7204              0.037           8.071   12526964  16275763662
# 7205              0.027           9.375   12697728  17918380597
# 7206              0.042          10.790   12894323  19554073776
# 7207              0.044          10.778   13115149  20909967517
#
#       Primary Energy Consumption
# 0                          2.950
# 1                          3.018
# 2                          3.131
# 3                          3.257
# 4                          3.279
# ...                          ...
# 7203                      41.277
# 7204                      41.112
# 7205                      46.599
# 7206                      51.260
# 7207                      55.756
#
# [7208 rows x 21 columns]

# %%
country_cursor.close()
Countries_Info.close()

# %% [markdown]
# ## Preparing columns to integrate the Record_ID column into the PSD dataframe

# %%
PrimaryAutoGrains = Country_DF[['Record_ID', 'Country', 'Year']]

# %%
PrimaryAutoGrains.rename(columns = {'Country':'Country_Name', 'Year': 'Market_Year'}, inplace = True)
# Out:
# C:\Users\rho25\AppData\Local\Temp\ipykernel_17360\2006266999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PrimaryAutoGrains.rename(columns = {'Country':'Country_Name', 'Year': 'Market_Year'}, inplace = True)

# %%
PrimaryAutoGrains
# Out:
#       Record_ID Country_Name  Market_Year
# 0             1  Afghanistan         1960
# 1             2  Afghanistan         1961
# 2             3  Afghanistan         1962
# 3             4  Afghanistan         1963
# 4             5  Afghanistan         1964
# ...         ...          ...          ...
# 7203       7204     Zimbabwe         2008
# 7204       7205     Zimbabwe         2009
# 7205       7206     Zimbabwe         2010
# 7206       7207     Zimbabwe         2011
# 7207       7208     Zimbabwe         2012
#
# [7208 rows x 3 columns]

# %%
crops_sorted_new = pd.merge(PrimaryAutoGrains, crops_sorted , on = ['Country_Name', 'Market_Year'], how = 'left')

# %%
numeric_columns = crops_sorted_new.select_dtypes(include=['number']).columns

# %%
numeric_columns
# Out:
# Index(['Record_ID', 'Market_Year', 'Unnamed: 0', 'Commodity_Code',
#        'Area Harvested', 'Beginning Stocks', 'Ending Stocks', 'Exports',
#        'FSI Consumption', 'Feed Dom. Consumption', 'Imports',
#        'Milling Rate (.9999)', 'Production', 'Rough Production', 'TY Exports',
#        'TY Imp. from U.S.', 'TY Imports'],
#       dtype='object')

# %%
crops_sorted_new[numeric_columns] = crops_sorted_new[numeric_columns].fillna(0)
crops_sorted_new['Commodity_Description'] = crops_sorted_new["Commodity_Description"].fillna("Empty")

# %%
crops_sorted_new.isna().sum()
# Out:
# Record_ID                0
# Country_Name             0
# Market_Year              0
# Unnamed: 0               0
# Commodity_Code           0
# Commodity_Description    0
# Area Harvested           0
# Beginning Stocks         0
# Ending Stocks            0
# Exports                  0
# FSI Consumption          0
# Feed Dom. Consumption    0
# Imports                  0
# Milling Rate (.9999)     0
# Production               0
# Rough Production         0
# TY Exports               0
# TY Imp. from U.S.        0
# TY Imports               0
# dtype: int64

# %%
crops_sorted_new.drop(['Country_Name', 'Market_Year', 'Unnamed: 0'], axis=1, inplace=True)

# %%
crops_data = crops_sorted_new.values.tolist()

# %% [markdown]
# ## Inserting PSD Data into the Grains Table

# %%
# Creating a connection to your MySQL Server 
# Put your MySQL Server/Workbench password
Grains_Info = mysql.connector.connect(
    host='localhost',
    user='root',
    passwd='your_password',
    database = 'global_country_info')

if (Grains_Info):
    print("Connection Successful")
else:
    print("Connection Failed")
# Out:
# Connection Successful

# %%
# Create a cursor from the connection made
grains_cursor = Grains_Info.cursor() 
    
grains_statement = "INSERT INTO Grains (Record_ID, Commodity_ID, Commodity_Description, Area_Harvested_HA, Beginning_Stocks_MT, Ending_Stocks_MT, Exports_MT, FSI_Consumption_MT, Feed_Dom_Consumption_MT, Imports_MT, Milling_Rate_MT, Production_MT ,Rough_Production_MT, TY_Exports_MT, TY_Imports_from_US_MT, TY_Imports_MT) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
                  
grains_cursor.executemany(grains_statement, crops_data)
  
Grains_Info.commit()
    
grains_cursor.execute("SELECT * FROM Grains;")
grains_results_final = grains_cursor.fetchall()

# %%
# Using the grain_results saved from the previous Query to insert
# Into a Pandas DataFrame to be used later
Grain_DF = pd.DataFrame(grains_results_final, columns= ["Grains_Record_ID", "Record_ID","Commodity_ID", "Commodity_Description", "Area_Harvested_HA", "Beginning_Stocks_MT", "Ending_Stocks_MT", "Imports_MT", "Exports_MT", "Feed_Dom_Consumption_MT", "FSI_Consumption_MT", "Production_MT", "TY_Imports_MT", "TY_Imports_from_US_MT", "TY_Exports_MT", "Milling_Rate_MT", "Rough_Production_MT"])

# %%
grains_cursor.close()
Grains_Info.close()

# %%
Grain_DF.set_index("Grains_Record_ID", inplace=True)

# %%
Grain_DF
# Out:
#                   Record_ID  Commodity_ID Commodity_Description  \
# Grains_Record_ID
# 1                         1        410000                 Wheat
# 2                         1        422110          Rice, Milled
# 3                         1        430000                Barley
# 4                         1        440000                  Corn
# 5                         2        410000                 Wheat
# ...                     ...           ...                   ...
# 27489                  7208        410000                 Wheat
# 27490                  7208        430000                Barley
# 27491                  7208        440000                  Corn
# 27492                  7208        459100                Millet
# 27493                  7208        459200               Sorghum
#
#                   Area_Harvested_HA  Beginning_Stocks_MT  Ending_Stocks_MT  \
# Grains_Record_ID
# 1                           2230000                    0                 0
# 2                            207000                    0                 0
# 3                            350000                    0                 0
# 4                            500000                    0                 0
# 5                           2230000                    0                 0
# ...                             ...                  ...               ...
# 27489                         10000                52000             36000
# 27490                          9000                 4000              4000
# 27491                       1281000                25000             15000
# 27492                        203000                    0                 0
# 27493                        217000                    0                 0
#
#                   Imports_MT  Exports_MT  Feed_Dom_Consumption_MT  \
# Grains_Record_ID
# 1                      51000           0                        0
# 2                          0           0                        0
# 3                          0           0                        0
# 4                          0           0                        0
# 5                      15000           0                        0
# ...                      ...         ...                      ...
# 27489                 250000           0                        0
# 27490                  15000           0                     5000
# 27491                 600000           0                    80000
# 27492                      0           0                        0
# 27493                   5000           0                     5000
#
#                   FSI_Consumption_MT  Production_MT  TY_Imports_MT  \
# Grains_Record_ID
# 1                            2330000        2279000          51000
# 2                                  0         203000              0
# 3                             378000         378000              0
# 4                             700000         700000              0
# 5                            2294000        2279000          15000
# ...                              ...            ...            ...
# 27489                         300000          34000         250000
# 27490                          61000          51000          15000
# 27491                        1529000         999000         700000
# 27492                          44000          44000              0
# 27493                          44000          44000           5000
#
#                   TY_Imports_from_US_MT  TY_Exports_MT  Milling_Rate_MT  \
# Grains_Record_ID
# 1                                 46000              0                0
# 2                                     0              0          6500000
# 3                                     0              0                0
# 4                                     0              0                0
# 5                                 15000              0                0
# ...                                 ...            ...              ...
# 27489                                 0              0                0
# 27490                                 0              0                0
# 27491                                 0              0                0
# 27492                                 0              0                0
# 27493                                 0              0                0
#
#                   Rough_Production_MT
# Grains_Record_ID
# 1                                   0
# 2                              313000
# 3                                   0
# 4                                   0
# 5                                   0
# ...                               ...
# 27489                               0
# 27490                               0
# 27491                               0
# 27492                               0
# 27493                               0
#
# [27493 rows x 16 columns]

# %% [markdown]
# ## Checking for consistencies between the original datasets and finalized integrated database

# %%
finalized = pd.read_csv('IntegratedData.csv')

# %%
testIntegrate = (finalized.loc[(finalized['W_Country'] == 'Brazil') & (finalized['W_Year'] == 2010)])

# %%
testco2 = (co2_sorted.loc[(co2_sorted['country'] == 'Brazil') & (co2_sorted['year'] == 2010)])

# %%
testCrops= (crops_sorted.loc[(crops_sorted['Country_Name'] == 'Brazil') & (crops_sorted['Market_Year'] == 2010)])

# %% [markdown]
# ## Comparing Commodities data

# %%
testCrops[['Commodity_Description', 'Area Harvested', 'Imports']]
# Out:
#       Commodity_Description  Area Harvested    Imports
# 652                   Wheat       2150000.0  6693000.0
# 5923           Rice, Milled       2833000.0   632000.0
# 11038                Barley         88000.0   324000.0
# 14109                  Corn      13800000.0   791000.0
# 18850                   Rye          2000.0        0.0
# 19932                  Oats        154000.0        0.0
# 23534               Sorghum        817000.0     1000.0

# %%
testIntegrate[['Commodity_Description', 'Area_Harvested_HA', 'Imports_MT']]
# Out:
#      Commodity_Description  Area_Harvested_HA  Imports_MT
# 3379                 Wheat            2150000     6693000
# 3380          Rice, Milled            2833000      632000
# 3381                Barley              88000      324000
# 3382                  Corn           13800000      791000
# 3383                   Rye               2000           0
# 3384                  Oats             154000           0
# 3385               Sorghum             817000        1000

# %% [markdown]
# ## Comparing CO2 Data

# %%
testco2[['population', 'gdp', 'methane']]
# Out:
#       population           gdp  methane
# 876  195713637.0  2.816706e+12    421.5

# %%
testIntegrate[['Population', 'GDP', 'Methane']]
# Out:
#       Population            GDP  Methane
# 3379   195713637  2816706146073    421.5
# 3380   195713637  2816706146073    421.5
# 3381   195713637  2816706146073    421.5
# 3382   195713637  2816706146073    421.5
# 3383   195713637  2816706146073    421.5
# 3384   195713637  2816706146073    421.5
# 3385   195713637  2816706146073    421.5
